# %% [markdown]
# # Saunois inventory
#
# This inventory is for methane emissions from natural sources.
#
# See :py:class:`emiproc.inventories.saunois.Saunois` for more details.

# %%
from emiproc.inventories.saunois import Saunois
from emiproc.plots import plot_inventory
import matplotlib.pyplot as plt

plt.style.use("default")

# %%
saunois_file = '/path/to/GCP_Prior_CH4_fluxes.nc'

inv = Saunois(saunois_file, year=2019)
inv.categories
# Out:
# ['freshwaters',
#  'biomass',
#  'oilgasind',
#  'termites',
#  'rice',
#  'geological',
#  'ocean',
#  'coal',
#  'wetlands',
#  'biofuels',
#  'soils',
#  'waste',
#  'livestock']

# %%
# Load only  a subset of sectors
inv = Saunois(saunois_file, year=2019, sectors=["ocean", "freshwaters", "geological", "soils"])

# %%
plot_inventory(inv)
